# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
import csv 
from statistics import mean 
import glob2 
from sklearn.cluster import KMeans
manufacturers = [] 
new_list = []
with open('car_list.csv', 'rt') as f:
    reader = csv.reader(f)
    for row in reader:
        manufacturers.append(row[0])
manufacturers  = manufacturers[1:]
manufacturers_len = len(set(manufacturers))
print(manufacturers_len)
set_manunfacturers = set(manufacturers)
set_manunfacturers
# Out:
# 22
# {'Audi',
#  'BMW',
#  'Chevrolet',
#  'Datsun',
#  'Fiat',
#  'Force Motors',
#  'Ford',
#  'Honda',
#  'Hyundai',
#  'Jaguar',
#  'Land Rover',
#  'Mahindra',
#  'Maruti Suzuki',
#  'Mercedes-Benz',
#  'Mitsubishi',
#  'Nissan',
#  'Renault',
#  'Skoda',
#  'Tata',
#  'Toyota',
#  'Volkswagen',
#  'Volvo'}

# %%
cars  = []
with open('car_list.csv', 'rt') as f:
    reader = csv.reader(f)
    for row in reader:
        cars.append(row[1])
cars = cars[1:]
import re
count = 0
new_list = []

for m in set_manunfacturers:
    for car in cars:
        if str(m) in str(car):
            count = count+1
            small_list = []
            new_list.append((re.sub(str(m),"",str(car),count=1)).lower())
car_list = []

for list in new_list:
    car_list.append((' '.join(list.split(' ')[1:-1])).capitalize())
path = '/home/saksham/Desktop/majorproject/out1/*.csv'       
print(path)
outfile = open('finalfile.csv', 'w')
writer = csv.writer(outfile)
writer.writerow(['MANUFACTURERE', 'CAR', 'a', 'b'])
# Out:
# /home/saksham/Desktop/majorproject/out1/*.csv
# 23

# %%
for file in glob2.glob(path):
    print(file)
    for car in car_list:
        
        with open(file, 'rt') as f:
            x = []
            y = []
            reader = csv.reader(f)
            for row in reader:
                if row[1] == car:
                    c = car
                    x.append(2017-int(row[3])*100000)
                    y.append(int(row[2]))
            
            if len(x)>0:
                man = str(file).split('/')[-1]
                print(man)
                man1 = man.split('.')[0]
                print('running')
                nparray = np.empty(shape=[0, 2])
                xs = np.empty(shape=[0,1], dtype=np.float64)
                ys = np.empty(shape=[0,1], dtype=np.float64)
                no_of_clusters = len(set(x))
                for (a, b) in zip(x,y):
                    nparray = np.append(nparray, [[b,a]], axis=0)
                
                kmeans = KMeans(n_clusters=no_of_clusters)
                kmeans.fit(nparray)
                centroids = kmeans.cluster_centers_
                labels = kmeans.labels_
                if no_of_clusters == 8:
                    colors = ["g.", "r.","c.","b.","y.", "w.", "k.", "m."]
                elif no_of_clusters == 7:
                    colors = ["g.", "r.","c.","b.","y.", "w.", "k."]
                elif  no_of_clusters == 6:
                    colors = ["g.", "r.","c.","b.","y.", "w."]
                elif no_of_clusters == 5:
                    colors = ["g.", "r.","c.","b.","y."]
                elif no_of_clusters == 4:
                    colors = ["g.", "r.","c.","b."]
                elif no_of_clusters == 3:
                    colors = ["g.", "r.","c."]
                elif no_of_clusters == 2:
                    colors = ["g.", "r."]
                elif no_of_clusters == 1:
                    colors = ["g."]
                for i in range(len(nparray)):
                    plt.plot(nparray[i][0], nparray[i][1], colors[labels[i]], markersize=10)
                plt.scatter(centroids[:, 0], centroids[:, 1], marker="x", s=150, linewidths=5, zorder=10)
                plt.xlabel("Year")
                plt.ylabel("Price")
                fig1 = plt.gcf()
                plt.draw()
                fig1.savefig('clusteredimage/' + str(car) + '1.png')
                plt.close()
                ym = centroids[:,1]
                print(xm)
                xm = centroids[:,0]
                for i in xm:
                    xs = np.append(xs, [[int(i)/100000]])

                for j in ym:
                    ys = np.append(ys, [[j]]) 
                # solve for a and b
                def best_fit(X, Y):

                    xbar = sum(X)/len(X)
                    ybar = sum(Y)/len(Y)
                    n = len(X) # or len(Y)

                    numer = sum(xi*yi for xi,yi in zip(X, Y)) - n * xbar * ybar
                    denum = sum(xi**2 for xi in X) - n * xbar**2

                    b = numer / denum
                    a = ybar - b * xbar

                    print('best fit line:\ny = {:.2f} +  {:.2f}x'.format(a, b))

                    return a, b

                # solution
                a, b = best_fit(xs, ys)
                print('for ' + str(car))
                
                print(a, b)
                print('before plot ')
                print(xs, ys)
                plt.scatter(xs, ys)
                yfit = [a + b * xi for xi in xs]
                plt.plot(xs, yfit)
                plt.xlabel("Year")
                plt.ylabel("Price")
                plt.grid()
                fig1 = plt.gcf()
                plt.draw()
                fig1.savefig('bestfitimage/' + str(car) + '1.png')
                plt.close() 
                
#                 plt.grid()
#                 fig1 = plt.gcf()
#                 plt.draw()
                
#                 fig1.savefig('bestfitimage/' + str(car) + '.png')
                outfile = open('finalfile.csv', 'a')
                writer = csv.writer(outfile)
                writer.writerow([man1,car,a,b])
# Out:
# /home/saksham/Desktop/majorproject/out1/BMW.csv
# BMW.csv
# running
# [ 1070555.55555556   643761.83333333   583500.6097561   1800000.
#    727361.08333333  1468750.           848884.61538462]
# best fit line:
# y = -200818411.51 +  -22474.90x
# for X1
# -200818411.508 -22474.9008041
# before plot
# [ 15.1234   32.5      21.55     18.1      13.45908  37.       24.16666] [ -2.01151316e+08  -2.01597983e+08  -2.01222983e+08  -2.01267983e+08
#   -2.01097983e+08  -2.01597983e+08  -2.01431316e+08]
# BMW.csv
# running
# [ 1512340.66666667  3250000.          2155000.          1810000.1
#   1345908.63636364  3700000.          2416666.66666667]
# best fit line:
# y = -200708557.75 +  -18560.22x
# for X3
# -200708557.75 -18560.2180802
# before plot
# [ 28.29166  46.5      25.       35.       42.       29.91666] [ -2.01214650e+08  -2.01547983e+08  -2.01164650e+08  -2.01397983e+08
#   -2.01497983e+08  -2.01264650e+08]
# BMW.csv
# running
# [ 2829166.66666667  4650000.          2500000.          3500000.          4200000.
#   2991666.66666667]
# best fit line:
# y = -200786888.43 +  -10617.78x
# for X5
# -200786888.43 -10617.7764584
# before plot
# [ 57.53333  35.33333  23.       68.       16.     ] [ -2.01431316e+08  -2.01131316e+08  -2.00997983e+08  -2.01497983e+08
#   -2.00997983e+08]
# BMW.csv
# running
# [ 5753333.33333333  3533333.33333333  2300000.          6800000.          1600000.        ]
# best fit line:
# y = -200509866.67 +  -13651.57x
# for Z4
# -200509866.671 -13651.5675876
# before plot
# [ 37.79749  66.       44.5      46.     ] [ -2.00997983e+08  -2.01397983e+08  -2.01097983e+08  -2.01197983e+08]
# BMW.csv
# running
# [ 3779749.75  6600000.    4450000.    4600000.  ]
# best fit line:
# y = nan +  nanx
# for X6
# nan nan
# before plot
# [ 42.5] [ -2.01097983e+08]
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:74: RuntimeWarning: invalid value encountered in double_scalars
# /home/saksham/Desktop/majorproject/out1/Renault.csv
# Renault.csv
# running
# [ 4250000.]
# best fit line:
# y = -194030729.28 +  -1935359.01x
# for Kwid
# -194030729.275 -1935359.00892
# before plot
# [ 3.85833  3.91   ] [ -2.01497983e+08  -2.01597983e+08]
# Renault.csv
# running
# [ 385833.33333333  391000.        ]
# best fit line:
# y = -200790898.16 +  -109605.99x
# for Pulse
# -200790898.16 -109605.988756
# before plot
# [ 5.       3.54166  6.25   ] [ -2.01297983e+08  -2.01197983e+08  -2.01497983e+08]
# Renault.csv
# running
# [ 500000.          354166.33333333  625000.        ]
# best fit line:
# y = -200991014.03 +  -45187.13x
# for Scala
# -200991014.027 -45187.1295826
# before plot
# [ 6.525  5.626  4.95   6.31 ] [ -2.01347983e+08  -2.01297983e+08  -2.01197983e+08  -2.01177983e+08]
# Renault.csv
# running
# [ 652500.  562600.  495000.  631000.]
# best fit line:
# y = -201724097.95 +  19108.31x
# for Lodgy
# -201724097.946 19108.3106822
# before plot
# [  9.74     11.83333] [ -2.01537983e+08  -2.01497983e+08]
# Renault.csv
# running
# [  974000.          1183333.33333333]
# best fit line:
# y = -200935765.55 +  -56957.34x
# for Duster
# -200935765.552 -56957.3408354
# before plot
# [ 9.78684  6.85635  8.36196  7.32664  7.82603  7.4125 ] [ -2.01497983e+08  -2.01300066e+08  -2.01407074e+08  -2.01197983e+08
#   -2.01297983e+08  -2.01622983e+08]
# Renault.csv
# running
# [ 978684.21052632  685635.33333333  836196.96969697  732664.81481481
#   782603.71698113  741250.        ]
# best fit line:
# y = -201065361.60 +  -19382.46x
# for Fluence
# -201065361.602 -19382.4594909
# before plot
# [  5.52499   8.58333  14.        7.     ] [ -2.01131316e+08  -2.01364650e+08  -2.01297983e+08  -2.01147983e+08]
# Renault.csv
# running
# [  552499.83333333   858333.33333333  1400000.           700000.        ]
# best fit line:
# y = -200749419.58 +  -32741.86x
# for Koleos
# -200749419.581 -32741.860196
# before plot
# [ 16.       10.25     13.25     19.        9.99999] [ -2.01247983e+08  -2.01197983e+08  -2.01147983e+08  -2.01397983e+08
#   -2.00997983e+08]
# /home/saksham/Desktop/majorproject/out1/Hyundai.csv
# Hyundai.csv
# running
# [ 1600000.  1025000.  1325000.  1900000.   999999.]
# best fit line:
# y = -200392350.26 +  -334355.94x
# for Eon
# -200392350.265 -334355.937304
# before plot
# [ 3.4636   2.45628  2.83571  2.19947  2.64009  3.55363] [ -2.01497983e+08  -2.01197983e+08  -2.01397983e+08  -2.01097983e+08
#   -2.01297983e+08  -2.01597983e+08]
# Hyundai.csv
# running
# [ 346360.16        245628.63235294  283571.4047619   219947.36842105
#   264009.80392157  355363.54545455]
# best fit line:
# y = -200214130.20 +  -303630.68x
# for I10
# -200214130.197 -303630.679617
# before plot
# [ 3.24039  2.99238  4.01071  3.35999  3.53974  2.35381  2.7004 ] [ -2.01197983e+08  -2.00997983e+08  -2.01522983e+08  -2.01097983e+08
#   -2.01325831e+08  -2.00997983e+08  -2.01097983e+08]
# Hyundai.csv
# running
# [ 324039.992       299238.95522388  401071.46428571  336000.
#   353974.7721519   235381.14529915  270040.19587629]
# best fit line:
# y = -201749077.85 +  56008.07x
# for Xcent
# -201749077.855 56008.066085
# before plot
# [ 5.77304  6.17588  8.5      2.     ] [ -2.01397983e+08  -2.01545042e+08  -2.01197983e+08  -2.01597983e+08]
# Hyundai.csv
# running
# [ 577304.34782609  617588.23529412  850000.          200000.        ]
# best fit line:
# y = -200667442.79 +  -90188.16x
# for Verna
# -200667442.789 -90188.1648406
# before plot
# [  7.21974   3.8921    8.7306    6.15688  10.26352   5.14345   7.735  ] [ -2.01303178e+08  -2.00997983e+08  -2.01413135e+08  -2.01172289e+08
#   -2.01515630e+08  -2.01103865e+08  -2.01597983e+08]
# Hyundai.csv
# running
# [  721974.02597403   389210.52631579   873060.51515152   615688.24305556
#   1026352.94117647   514345.41176471   773500.        ]
# best fit line:
# y = -200796674.31 +  -45256.80x
# for Elantra
# -200796674.315 -45256.8002139
# before plot
# [  8.70125  13.80714  10.6375   10.65     12.0625 ] [ -2.01235483e+08  -2.01469412e+08  -2.01310483e+08  -2.01197983e+08
#   -2.01297983e+08]
# /home/saksham/Desktop/majorproject/out1/Mercedes-Benz.csv
# Mercedes-Benz.csv
# running
# [  870125.          1380714.28571429  1063750.          1065000.          1206250.        ]
# best fit line:
# y = -199764649.67 +  -47619.05x
# for Cls
# -199764649.667 -47619.0476199
# before plot
# [ 28.   25.9] [ -2.01097983e+08  -2.00997983e+08]
# /home/saksham/Desktop/majorproject/out1/Audi.csv
# Audi.csv
# running
# [ 2800000.  2590000.]
# best fit line:
# y = -201308283.37 +  -5775.50x
# for A3
# -201308283.373 -5775.50408207
# before plot
# [ 24.03666  50.       24.5    ] [ -2.01497983e+08  -2.01597983e+08  -2.01397983e+08]
# Audi.csv
# running
# [ 2403666.33333333  5000000.          2450000.        ]
# best fit line:
# y = -200496900.69 +  -31268.70x
# for Q3
# -200496900.689 -31268.6991106
# before plot
# [ 26.28571  31.       24.25     27.97222] [ -2.01412269e+08  -2.01447983e+08  -2.01197983e+08  -2.01353539e+08]
# Audi.csv
# running
# [ 2628571.42857143  3100000.          2425000.          2797222.22222222]
# best fit line:
# y = -200718519.83 +  -24015.80x
# for A4
# -200718519.83 -24015.7974219
# before plot
# [ 21.07692  17.725    36.51666  30.29999  14.88947  26.02777  23.86066] [ -2.01197983e+08  -2.01107983e+08  -2.01497983e+08  -2.01537983e+08
#   -2.01050615e+08  -2.01397983e+08  -2.01331316e+08]
# Audi.csv
# running
# [ 2107692.30769231  1772500.          3651666.66666667  3029999.8
#   1488947.31578947  2602777.77777778  2386066.53333333]
# best fit line:
# y = -200540282.87 +  -23112.00x
# for Q5
# -200540282.871 -23112.0041133
# before plot
# [ 21.2475   34.0025   41.       24.76     31.3      36.66666] [ -2.01047983e+08  -2.01347983e+08  -2.01497983e+08  -2.01119412e+08
#   -2.01197983e+08  -2.01397983e+08]
# Audi.csv
# running
# [ 2124750.          3400250.          4100000.          2476000.          3130000.
#   3666666.66666667]
# best fit line:
# y = -200715727.47 +  -18921.14x
# for A6
# -200715727.471 -18921.1403754
# before plot
# [ 18.64999  30.19999  36.346    23.21666  14.5375   27.30615] [ -2.01077983e+08  -2.01267983e+08  -2.01417983e+08  -2.01131316e+08
#   -2.00997983e+08  -2.01244137e+08]
# Audi.csv
# running
# [ 1864999.8         3019999.8         3634600.          2321666.66666667
#   1453750.          2730615.38461538]
# best fit line:
# y = nan +  nanx
# for Tt
# nan nan
# before plot
# [ 38.9] [ -2.01297983e+08]
# Audi.csv
# running
# [ 3890000.]
# best fit line:
# y = -200495698.88 +  -18645.17x
# for Q7
# -200495698.876 -18645.1664616
# before plot
# [ 39.3125  26.      44.8     54.5     35.125   41.9   ] [ -2.01172983e+08  -2.00997983e+08  -2.01314650e+08  -2.01497983e+08
#   -2.01097983e+08  -2.01397983e+08]
# Audi.csv
# running
# [ 3931250.  2600000.  4480000.  5450000.  3512500.  4190000.]
# best fit line:
# y = nan +  nanx
# for R8
# nan nan
# before plot
# [ 82.5] [ -2.01197983e+08]
# /home/saksham/Desktop/majorproject/out1/Honda.csv
# Honda.csv
# running
# [ 8250000.]
# best fit line:
# y = -201230575.92 +  -30793.42x
# for Brio
# -201230575.918 -30793.4155626
# before plot
# [ 3.48797  3.84535  4.875    4.35142  2.85     3.46666] [ -2.01197983e+08  -2.01297983e+08  -2.01497983e+08  -2.01397983e+08
#   -2.01597983e+08  -2.01097983e+08]
# Honda.csv
# running
# [ 348797.93181818  384535.67857143  487500.          435142.85714286
#   285000.          346666.66666667]
# best fit line:
# y = -200636166.44 +  -136757.15x
# for Amaze
# -200636166.441 -136757.147435
# before plot
# [ 5.34294  5.8626   5.149    6.08235  6.74583] [ -2.01296512e+08  -2.01497983e+08  -2.01397983e+08  -2.01397983e+08
#   -2.01581316e+08]
# Honda.csv
# running
# [ 534294.10294118  586260.86956522  514900.          608235.23529412
#   674583.33333333]
# best fit line:
# y = -200574138.98 +  -134795.43x
# for Jazz
# -200574138.977 -134795.432109
# before plot
# [ 3.46705  7.525    3.70999  4.3      6.7525   4.425  ] [ -2.00997983e+08  -2.01497983e+08  -2.01097983e+08  -2.01222983e+08
#   -2.01597983e+08  -2.01097983e+08]
# Honda.csv
# running
# [ 346705.88235294  752500.          370999.9         430000.          675250.
#   442500.        ]
# best fit line:
# y = -201529951.26 +  8609.37x
# for Mobilio
# -201529951.257 8609.3715675
# before plot
# [ 7.91347  7.461    8.8    ] [ -2.01397983e+08  -2.01507983e+08  -2.01475761e+08]
# Honda.csv
# running
# [ 791347.7826087  746100.         880000.       ]
# best fit line:
# y = -201053542.86 +  -39168.18x
# for City
# -201053542.858 -39168.1844671
# before plot
# [  6.62046   4.5132    9.34349   5.23554   6.10518  10.64782   4.14
#    8.29285] [ -2.01297983e+08  -2.00997983e+08  -2.01428142e+08  -2.01097983e+08
#   -2.01197983e+08  -2.01519722e+08  -2.01631316e+08  -2.01407507e+08]
# Honda.csv
# running
# [  662046.51162791   451320.53719008   934349.19047619   523554.04504505
#    610518.45679012  1064782.60869565   414000.           829285.5       ]
# best fit line:
# y = -201315082.73 +  8698.50x
# for Accord
# -201315082.733 8698.50236996
# before plot
# [  8.05388  16.25      9.91142   3.75      6.62624] [ -2.01081316e+08  -2.01297983e+08  -2.01212269e+08  -2.01597983e+08
#   -2.00997983e+08]
# /home/saksham/Desktop/majorproject/out1/Fiat.csv
# Fiat.csv
# running
# [  805388.83333333  1625000.           991142.85714286   375000.
#    662624.8125    ]
# best fit line:
# y = -200721527.60 +  -112274.87x
# for Linea
# -200721527.604 -112274.872679
# before plot
# [ 4.6485   2.65166  3.91875  2.9      4.65   ] [ -2.01197983e+08  -2.00997983e+08  -2.01097983e+08  -2.01097983e+08
#   -2.01322983e+08]
# /home/saksham/Desktop/majorproject/out1/Skoda.csv
# Skoda.csv
# running
# [ 464850.          265166.66666667  391875.          290000.          465000.        ]
# best fit line:
# y = -200875520.05 +  -67101.62x
# for Rapid
# -200875520.05 -67101.6153068
# before plot
# [  5.75767   7.89625   8.46666   4.87674   6.55166  10.09166] [ -2.01202745e+08  -2.01535483e+08  -2.01397983e+08  -2.01202634e+08
#   -2.01327983e+08  -2.01514650e+08]
# Skoda.csv
# running
# [  575767.19047619   789625.           846666.77777778   487674.18604651
#    655166.66666667  1009166.66666667]
# best fit line:
# y = -201233397.74 +  -12093.82x
# for Octavia
# -201233397.741 -12093.8201953
# before plot
# [ 10.6      19.5       4.85     14.37499   4.25   ] [ -2.01397983e+08  -2.01497983e+08  -2.01597983e+08  -2.01322983e+08
#   -2.00997983e+08]
# Skoda.csv
# running
# [ 1060000.  1950000.   485000.  1437499.   425000.]
# best fit line:
# y = -201074615.21 +  -20172.54x
# for Yeti
# -201074615.21 -20172.5352917
# before plot
# [  7.55     19.       10.325     7.75      8.9375    7.36666] [ -2.01197983e+08  -2.01497983e+08  -2.01122983e+08  -2.01597983e+08
#   -2.01172983e+08  -2.01086872e+08]
# Skoda.csv
# running
# [  755000.          1900000.          1032500.           775000.           893750.
#    736666.66666667]
# best fit line:
# y = -200721832.15 +  -42113.81x
# for Superb
# -200721832.149 -42113.8120455
# before plot
# [  6.70775  11.75     18.5       8.73312  14.35      9.75583] [ -2.01027983e+08  -2.01197983e+08  -2.01497983e+08  -2.01010483e+08
#   -2.01337983e+08  -2.01197983e+08]
# /home/saksham/Desktop/majorproject/out1/Maruti Suzuki.csv
# Maruti Suzuki.csv
# running
# [  670775.          1175000.          1850000.           873312.5
#   1435000.2          975583.08333333]
# best fit line:
# y = -200417068.52 +  -349714.95x
# for Alto 800
# -200417068.517 -349714.953723
# before plot
# [ 2.49637  3.08428  2.66284  2.26     3.40416  2.15     1.575  ] [ -2.01297983e+08  -2.01497983e+08  -2.01397983e+08  -2.01197983e+08
#   -2.01597983e+08  -2.01097983e+08  -2.00997983e+08]
# Maruti Suzuki.csv
# running
# [ 249637.93103448  308428.53571429  266284.09090909  226000.
#   340416.66666667  215000.          157500.        ]
# best fit line:
# y = -200312573.59 +  -436966.23x
# for Omni
# -200312573.586 -436966.231044
# before plot
# [ 2.875    1.74193  2.4      2.09563  1.56787  2.63     2.47538] [ -2.01597983e+08  -2.01097983e+08  -2.01297983e+08  -2.01197983e+08
#   -2.00997983e+08  -2.01397983e+08  -2.01497983e+08]
# Maruti Suzuki.csv
# running
# [ 287500.          174193.5483871   240000.          209563.15789474
#   156787.87878788  263000.          247538.46153846]
# best fit line:
# y = -200346446.52 +  -321036.46x
# for Eeco
# -200346446.518 -321036.462682
# before plot
# [ 3.19105  2.27586  3.70884  2.81862  2.55461  2.29868  3.9    ] [ -2.01397983e+08  -2.01097983e+08  -2.01497983e+08  -2.01297983e+08
#   -2.01197983e+08  -2.00997983e+08  -2.01597983e+08]
# Maruti Suzuki.csv
# running
# [ 319105.26315789  227586.97826087  370884.61538462  281862.06896552
#   255461.53846154  229868.42105263  390000.        ]
# best fit line:
# y = -200671900.91 +  -176851.55x
# for Celerio
# -200671900.906 -176851.548932
# before plot
# [ 4.30592  4.38785  4.94615  5.02333] [ -2.01394279e+08  -2.01497983e+08  -2.01497983e+08  -2.01597983e+08]
# Maruti Suzuki.csv
# running
# [ 430592.59259259  438785.71428571  494615.38461538  502333.33333333]
# best fit line:
# y = -200348485.56 +  -193250.37x
# for Swift
# -200348485.557 -193250.366111
# before plot
# [ 3.37377  5.38849  5.80951  3.94152  5.41199  4.5618   4.49553] [ -2.00997983e+08  -2.01297983e+08  -2.01525402e+08  -2.01097983e+08
#   -2.01397983e+08  -2.01197983e+08  -2.01297983e+08]
# Maruti Suzuki.csv
# running
# [ 337377.86259542  538850.          580951.61290323  394152.46808511
#   541199.9875      456180.18978102  449553.55357143]
# best fit line:
# y = -201049711.01 +  -68690.64x
# for Baleno
# -201049711.01 -68690.6393133
# before plot
# [ 3.75     8.21416  5.43   ] [ -2.01197983e+08  -2.01547983e+08  -2.01597983e+08]
# Maruti Suzuki.csv
# running
# [ 375000.          821416.66666667  543000.        ]
# best fit line:
# y = -201257690.71 +  17362.51x
# for Gypsy
# -201257690.713 17362.5125861
# before plot
# [ 2.4      4.91666  3.     ] [ -2.01297983e+08  -2.01197983e+08  -2.01097983e+08]
# Maruti Suzuki.csv
# running
# [ 240000.          491666.66666667  300000.        ]
# best fit line:
# y = -201623672.38 +  37118.42x
# for Ertiga
# -201623672.377 37118.4201347
# before plot
# [ 6.55166  7.76594  6.07384  7.44313  3.3    ] [ -2.01297983e+08  -2.01500615e+08  -2.01197983e+08  -2.01368132e+08
#   -2.01597983e+08]
# Maruti Suzuki.csv
# running
# [ 655166.66666667  776594.73684211  607384.6025641   744313.41791045
#   330000.        ]
# best fit line:
# y = -201050248.75 +  -51384.49x
# for Ciaz
# -201050248.749 -51384.4882897
# before plot
# [ 10.68418   7.88055   9.09898] [ -2.01597983e+08  -2.01453539e+08  -2.01520710e+08]
# /home/saksham/Desktop/majorproject/out1/Mitsubishi.csv
# /home/saksham/Desktop/majorproject/out1/Nissan.csv
# Nissan.csv
# running
# [ 1068418.75         788055.55555556   909898.81818182]
# best fit line:
# y = -200441267.01 +  -221907.71x
# for Micra
# -200441267.013 -221907.708307
# before plot
# [ 4.04375  2.84642  3.36714  4.42857  2.33875  3.53636  4.275  ] [ -2.01297983e+08  -2.01097983e+08  -2.01197983e+08  -2.01512269e+08
#   -2.00997983e+08  -2.01097983e+08  -2.01397983e+08]
# Nissan.csv
# running
# [ 404375.          284642.85714286  336714.28571429  442857.14285714
#   233875.          353636.36363636  427500.        ]
# best fit line:
# y = -201425575.96 +  13944.80x
# for Sunny
# -201425575.963 13944.8024569
# before plot
# [ 5.10321  5.83333  4.24956  2.95     5.81045  7.48125] [ -2.01201554e+08  -2.01414650e+08  -2.01167548e+08  -2.01597983e+08
#   -2.01297983e+08  -2.01435483e+08]
# Nissan.csv
# running
# [ 510321.28571429  583333.33333333  424956.52173913  295000.
#   581045.45454545  748125.        ]
# best fit line:
# y = -201288720.75 +  -16454.94x
# for Terrano
# -201288720.753 -16454.9437333
# before plot
# [  9.95263   8.47249   8.49999  11.01666] [ -2.01376930e+08  -2.01522983e+08  -2.01364650e+08  -2.01514650e+08]
# /home/saksham/Desktop/majorproject/out1/Volkswagen.csv
# Volkswagen.csv
# running
# [  995263.21052632   847249.75         849999.88888889  1101666.66666667]
# best fit line:
# y = -200684060.75 +  -118669.55x
# for Polo
# -200684060.751 -118669.54502
# before plot
# [ 3.66368  5.76547  3.4979   6.76785  4.54822  3.24169  4.75621] [ -2.01197983e+08  -2.01333697e+08  -2.01097983e+08  -2.01490840e+08
#   -2.01197983e+08  -2.00997983e+08  -2.01297983e+08]
# Volkswagen.csv
# running
# [ 366368.36842105  576547.61904762  349790.94897959  676785.66666667
#   454822.22222222  324169.23913043  475621.13793103]
# best fit line:
# y = -200749179.43 +  -77010.84x
# for Vento
# -200749179.431 -77010.8371176
# before plot
# [  4.07969   8.49545   5.23418   4.7747   10.35      4.3394    6.71689] [ -2.01097983e+08  -2.01425256e+08  -2.01197983e+08  -2.01097983e+08
#   -2.01513368e+08  -2.00997983e+08  -2.01301431e+08]
# Volkswagen.csv
# running
# [  407969.16923077   849545.36363636   523418.10447761   477470.92537313
#   1035000.           433940.90625      671689.62068966]
# best fit line:
# y = -200874400.29 +  -30224.91x
# for Jetta
# -200874400.292 -30224.9089061
# before plot
# [  6.25882  14.45     10.17444  23.       18.16666   4.66498   7.98636] [ -2.01062689e+08  -2.01397983e+08  -2.01197983e+08  -2.01497983e+08
#   -2.01464650e+08  -2.00997983e+08  -2.01061619e+08]
# Volkswagen.csv
# running
# [  625882.35294118  1445000.          1017444.44444444  2300000.
#   1816666.66666667   466498.33333333   798636.36363636]
# best fit line:
# y = -201695616.14 +  39053.25x
# for Beetle
# -201695616.136 39053.2544379
# before plot
# [ 14.75  18.5   16.5 ] [ -2.01147983e+08  -2.00997983e+08  -2.00997983e+08]
# /home/saksham/Desktop/majorproject/out1/Mahindra.csv
# Mahindra.csv
# running
# [ 1475000.  1850000.  1650000.]
# best fit line:
# y = -201320195.80 +  -5460.40x
# for Thar
# -201320195.801 -5460.39790395
# before plot
# [ 5.91    7.58    3.35    9.7125  7.3375  5.8   ] [ -2.01197983e+08  -2.01397983e+08  -2.01597983e+08  -2.01547983e+08
#   -2.01297983e+08  -2.01097983e+08]
# Mahindra.csv
# running
# [ 591000.  758000.  335000.  971250.  733750.  580000.]
# best fit line:
# y = -201022774.66 +  -49694.97x
# for Bolero
# -201022774.664 -49694.9709778
# before plot
# [ 4.44476  5.24267  7.48     6.13769  4.76055  6.84999  3.85   ] [ -2.00997983e+08  -2.01197983e+08  -2.01497983e+08  -2.01297983e+08
#   -2.01097983e+08  -2.01397983e+08  -2.01597983e+08]
# Mahindra.csv
# running
# [ 444476.14285714  524267.89285714  748000.          613769.23076923
#   476055.44444444  684999.94117647  385000.        ]
# best fit line:
# y = -200919328.91 +  -90100.33x
# for Verito
# -200919328.908 -90100.3279649
# before plot
# [ 3.60999  5.73     4.24818  7.6      4.00833  3.21666  2.7    ] [ -2.01097983e+08  -2.01477983e+08  -2.01297983e+08  -2.01597983e+08
#   -2.01197983e+08  -2.01497983e+08  -2.01070710e+08]
# Mahindra.csv
# running
# [ 360999.93333333  573000.          424818.18181818  760000.
#   400833.33333333  321666.66666667  270000.        ]
# best fit line:
# y = -200931888.18 +  -64585.25x
# for Xylo
# -200931888.181 -64585.2469242
# before plot
# [ 3.61975  4.67295  6.1445   8.66666  5.31833  3.13333  4.09038] [ -2.00997983e+08  -2.01225852e+08  -2.01362983e+08  -2.01597983e+08
#   -2.01044650e+08  -2.01497983e+08  -2.01097983e+08]
# Mahindra.csv
# running
# [ 361975.          467295.08196721  614450.          866666.66666667
#   531833.3         313333.33333333  409038.92307692]
# best fit line:
# y = -200462486.96 +  -101045.23x
# for Scorpio
# -200462486.963 -101045.232217
# before plot
# [  5.42395   8.3709    6.31268  10.95      6.85647   9.25166   6.29933] [ -2.00997983e+08  -2.01320710e+08  -2.01097983e+08  -2.01447983e+08
#   -2.01212499e+08  -2.01564650e+08  -2.00997983e+08]
# Mahindra.csv
# running
# [  542395.79166667   837090.88636364   631268.26829268  1095000.
#    685647.11290323   925166.66666667   629933.33333333]
# best fit line:
# y = -200792553.38 +  -48356.71x
# for Xuv500
# -200792553.376 -48356.712135
# before plot
# [  8.20144  12.33593  16.219     9.73198  14.225    11.05045] [ -2.01178706e+08  -2.01372983e+08  -2.01527983e+08  -2.01241120e+08
#   -2.01547983e+08  -2.01356807e+08]
# /home/saksham/Desktop/majorproject/out1/Tata.csv
# Tata.csv
# running
# [  820144.54216867  1233593.75        1621900.           973198.01960784
#   1422500.          1105045.67647059]
# best fit line:
# y = -200969916.01 +  -228282.12x
# for Nano
# -200969916.007 -228282.120384
# before plot
# [ 0.68587  1.56071  0.87762  0.70828  2.06     1.11111  3.1    ] [ -2.00997983e+08  -2.01397983e+08  -2.01197983e+08  -2.01097983e+08
#   -2.01507983e+08  -2.01297983e+08  -2.01597983e+08]
# Tata.csv
# running
# [  68587.26785714  156071.48         87762.19512195   70828.25373134
#   206000.          111111.          310000.        ]
# best fit line:
# y = -201246617.18 +  17200.77x
# for Venture
# -201246617.179 17200.7704479
# before plot
# [ 2.79187  2.3      2.35     1.93   ] [ -2.01197983e+08  -2.01331316e+08  -2.01097983e+08  -2.01197983e+08]
# Tata.csv
# running
# [ 279187.16666667  230000.          235000.          193000.        ]
# best fit line:
# y = -200635297.25 +  -137512.97x
# for Zest
# -200635297.245 -137512.970414
# before plot
# [ 5.66666  6.275    7.     ] [ -2.01414650e+08  -2.01497983e+08  -2.01597983e+08]
# Tata.csv
# running
# [ 566666.66666667  627500.          700000.        ]
# best fit line:
# y = -200662053.17 +  -95841.06x
# for Safari
# -200662053.175 -95841.0556601
# before plot
# [ 4.72941  4.13523  5.71785  7.25     4.63625] [ -2.01097983e+08  -2.00997983e+08  -2.01205126e+08  -2.01347983e+08
#   -2.01197983e+08]
# Tata.csv
# running
# [ 472941.17647059  413523.80952381  571785.71428571  725000.          463625.        ]
# best fit line:
# y = -200663728.70 +  -99526.00x
# for Aria
# -200663728.698 -99525.9953855
# before plot
# [ 6.73333  4.75     5.4      5.81666  6.85     4.5    ] [ -2.01197983e+08  -2.01347983e+08  -2.01097983e+08  -2.01231316e+08
#   -2.01497983e+08  -2.00997983e+08]
# /home/saksham/Desktop/majorproject/out1/Ford.csv
# Ford.csv
# running
# [ 673333.33333333  475000.          540000.          581666.66666667
#   685000.          450000.        ]
# best fit line:
# y = -200653736.26 +  -172849.32x
# for Figo
# -200653736.26 -172849.315345
# before plot
# [ 2.87627  3.86896  3.39779  3.33     3.175    4.44037  2.65047] [ -2.00997983e+08  -2.01297983e+08  -2.01197983e+08  -2.01097983e+08
#   -2.01572983e+08  -2.01416502e+08  -2.01097983e+08]
# Ford.csv
# running
# [ 287627.27272727  386896.55172414  339779.01136364  333000.          317500.
#   444037.03703704  265047.61904762]
# best fit line:
# y = -200689422.65 +  -88544.25x
# for Ecosport
# -200689422.645 -88544.2532185
# before plot
# [  7.98227   7.46032   8.62086  10.43125   6.73689] [ -2.01397983e+08  -2.01294757e+08  -2.01502331e+08  -2.01597983e+08
#   -2.01304880e+08]
# Ford.csv
# running
# [  798227.3255814    746032.06451613   862086.95652174  1043125.
#    673689.5862069 ]
# best fit line:
# y = -201283010.89 +  -1945.80x
# for Endeavour
# -201283010.887 -1945.79911479
# before plot
# [  8.62916  11.18076   7.25     15.       10.7       9.00111] [ -2.00997983e+08  -2.01167214e+08  -2.01597983e+08  -2.01347983e+08
#   -2.01597983e+08  -2.01109094e+08]
# /home/saksham/Desktop/majorproject/out1/Toyota.csv
# Toyota.csv
# running
# [  862916.625       1118076.92307692   725000.          1500000.          1070000.
#    900111.11111111]
# best fit line:
# y = -200593859.35 +  -33726.49x
# for Fortuner
# -200593859.349 -33726.4886564
# before plot
# [ 21.76043  12.85727  27.64357  17.4167   24.24781  14.26896  19.71   ] [ -2.01319722e+08  -2.01000924e+08  -2.01519412e+08  -2.01197983e+08
#   -2.01410483e+08  -2.01087638e+08  -2.01271896e+08]
# Toyota.csv
# running
# [ 2176043.43478261  1285727.88235294  2764357.14285714  1741670.
#   2424781.28125     1426896.55172414  1971000.        ]
# best fit line:
# y = -200851433.08 +  -21530.87x
# for Camry
# -200851433.085 -21530.8698511
# before plot
# [  8.75666  16.        6.5    ] [ -2.01031316e+08  -2.01197983e+08  -2.00997983e+08]
# Toyota.csv
# running
# [  875666.66666667  1600000.           650000.        ]
# best fit line:
# y = nan +  nanx
# for Prius
# nan nan
# before plot
# [ 12.99999] [ -2.01097983e+08]
# /home/saksham/Desktop/majorproject/out1/Chevrolet.csv
# Chevrolet.csv
# running
# [ 1299999.]
# best fit line:
# y = -201202014.74 +  -7898.80x
# for Spark
# -201202014.745 -7898.80085124
# before plot
# [ 2.22675  1.71888  2.804    1.93     1.8      1.65   ] [ -2.01097983e+08  -2.00997983e+08  -2.01317983e+08  -2.01197983e+08
#   -2.01097983e+08  -2.01597983e+08]
# Chevrolet.csv
# running
# [ 222675.08333333  171888.88888889  280400.          193000.          180000.
#   165000.        ]
# best fit line:
# y = -200536523.00 +  -232106.65x
# for Beat
# -200536522.997 -232106.649593
# before plot
# [ 2.12372  3.00705  4.25714  2.53262  3.36242  2.46199  3.61934] [ -2.00997983e+08  -2.01197983e+08  -2.01526554e+08  -2.01097983e+08
#   -2.01297983e+08  -2.01197983e+08  -2.01397983e+08]
# Chevrolet.csv
# running
# [ 212372.76470588  300705.82352941  425714.28571429  253262.4625
#   336242.42424242  246199.91111111  361934.11764706]
# best fit line:
# y = -201115210.83 +  -52617.12x
# for Sail
# -201115210.833 -52617.1180533
# before plot
# [ 3.46666  5.125    4.68   ] [ -2.01314650e+08  -2.01431316e+08  -2.01297983e+08]
# Chevrolet.csv
# running
# [ 346666.66666667  512500.          468000.        ]
# best fit line:
# y = -201384302.74 +  4515.57x
# for Enjoy
# -201384302.738 4515.57430864
# before plot
# [ 5.37166  4.30725  1.455    5.15571  2.275    6.6    ] [ -2.01297983e+08  -2.01297983e+08  -2.01597983e+08  -2.01412269e+08
#   -2.01147983e+08  -2.01437983e+08]
# Chevrolet.csv
# running
# [ 537166.66666667  430725.57894737  145500.          515571.42857143
#   227500.          660000.        ]
# best fit line:
# y = -200922441.99 +  -65054.60x
# for Tavera
# -200922441.99 -65054.597495
# before plot
# [ 4.48611  7.18133  5.77857  9.8      4.63333  8.075    4.4    ] [ -2.01097983e+08  -2.01371316e+08  -2.01231316e+08  -2.01597983e+08
#   -2.00997983e+08  -2.01447983e+08  -2.01597983e+08]
# Chevrolet.csv
# running
# [ 448611.11111111  718133.33333333  577857.19047619  980000.
#   463333.33333333  807500.          440000.        ]
# best fit line:
# y = -200805514.98 +  -43952.32x
# for Cruze
# -200805514.976 -43952.3212029
# before plot
# [  7.27361  18.       10.70555   5.835    14.6875    8.48884   6.43761] [ -2.01064650e+08  -2.01547983e+08  -2.01342427e+08  -2.00997983e+08
#   -2.01472983e+08  -2.01232598e+08  -2.01119412e+08]
