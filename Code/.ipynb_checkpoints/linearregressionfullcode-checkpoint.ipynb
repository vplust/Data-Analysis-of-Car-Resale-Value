# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
import csv 
from statistics import mean 
import glob2 
from sklearn.cluster import KMeans
manufacturers = [] 
new_list = []
with open('car_list.csv', 'rt') as f:
    reader = csv.reader(f)
    for row in reader:
        manufacturers.append(row[0])
manufacturers  = manufacturers[1:]
manufacturers_len = len(set(manufacturers))
print(manufacturers_len)
set_manunfacturers = set(manufacturers)
set_manunfacturers
# Out:
# 22
# {'Audi',
#  'BMW',
#  'Chevrolet',
#  'Datsun',
#  'Fiat',
#  'Force Motors',
#  'Ford',
#  'Honda',
#  'Hyundai',
#  'Jaguar',
#  'Land Rover',
#  'Mahindra',
#  'Maruti Suzuki',
#  'Mercedes-Benz',
#  'Mitsubishi',
#  'Nissan',
#  'Renault',
#  'Skoda',
#  'Tata',
#  'Toyota',
#  'Volkswagen',
#  'Volvo'}

# %%
cars  = []
with open('car_list.csv', 'rt') as f:
    reader = csv.reader(f)
    for row in reader:
        cars.append(row[1])
cars = cars[1:]
import re
count = 0
new_list = []

for m in set_manunfacturers:
    for car in cars:
        if str(m) in str(car):
            count = count+1
            small_list = []
            new_list.append((re.sub(str(m),"",str(car),count=1)).lower())
car_list = []

for list in new_list:
    car_list.append((' '.join(list.split(' ')[1:-1])).capitalize())
path = '/home/saksham/Desktop/majorproject/out1/*.csv'       
print(path)
outfile = open('finalfile.csv', 'w')
writer = csv.writer(outfile)
writer.writerow(['MANUFACTURERE', 'CAR', 'a', 'b'])
# Out:
# /home/saksham/Desktop/majorproject/out1/*.csv
# 23

# %%
for file in glob2.glob(path):
    print(file)
    for car in car_list:
        
        with open(file, 'rt') as f:
            x = []
            y = []
            reader = csv.reader(f)
            for row in reader:
                if row[1] == car:
                    c = car
                    x.append(int(2017 - int(row[3])))
                    y.append(int(row[2]))
            
            if len(x)>0:
                man = str(file).split('/')[-1]
                print(man)
                man1 = man.split('.')[0]
                print('running')
                nparray = np.empty(shape=[0, 2])
                xs = np.empty(shape=[0,1], dtype=np.float64)
                ys = np.empty(shape=[0,1], dtype=np.float64)
                print('xs')
                print(xs)
                
                no_of_clusters = len(set(x))
                for (a, b) in zip(x,y):
                    nparray = np.append(nparray, [[a,b]], axis=0)
                
                kmeans = KMeans(n_clusters=no_of_clusters)
                kmeans.fit(nparray)
                centroids = kmeans.cluster_centers_
                labels = kmeans.labels_
                if no_of_clusters == 8:
                    colors = ["g.", "r.","c.","b.","y.", "w.", "k.", "m."]
                elif no_of_clusters == 7:
                    colors = ["g.", "r.","c.","b.","y.", "w.", "k."]
                elif  no_of_clusters == 6:
                    colors = ["g.", "r.","c.","b.","y.", "w."]
                elif no_of_clusters == 5:
                    colors = ["g.", "r.","c.","b.","y."]
                elif no_of_clusters == 4:
                    colors = ["g.", "r.","c.","b."]
                elif no_of_clusters == 3:
                    colors = ["g.", "r.","c."]
                elif no_of_clusters == 2:
                    colors = ["g.", "r."]
                elif no_of_clusters == 1:
                    colors = ["g."]
#                for i in range(len(nparray)):
                    
#                    plt.plot(nparray[i][0], nparray[i][1], colors[labels[i]], markersize=10)
#                 plt.scatter(centroids[:, 0], centroids[:, 1], marker="x", s=150, linewidths=5, zorder=10)
#                 plt.xlabel("Year")
#                 plt.ylabel("Price")
#                 fig1 = plt.gcf()
#                 plt.draw()
#                 fig1.savefig('clusteredimage/' + str(car) + '.png')
                ym = centroids[:,1]
                xm = centroids[:,0]
                for i in xm:
                    xs = np.append(xs, [[i]])

                for j in ym:
                    print(j)
                    ys = np.append(ys, [[j]]) 
                # solve for a and b
                def best_fit(X, Y):

                    xbar = sum(X)/len(X)
                    ybar = sum(Y)/len(Y)
                    n = len(X) # or len(Y)

                    numer = sum(xi*yi for xi,yi in zip(X, Y)) - n * xbar * ybar
                    denum = sum(xi**2 for xi in X) - n * xbar**2

                    b = numer / denum
                    a = ybar - b * xbar

                    print('best fit line:\ny = {:.2f} +  {:.2f}x'.format(a, b))

                    return a, b

                # solution
                a, b = best_fit(xs, ys)
                print(a,b)
                plt.scatter(xs, ys)
                plt.xlabel("Year")
                plt.ylabel("Price")
                yfit = [a + b * xi for xi in xs]
                plt.plot(xs, yfit)
                plt.grid()
                fig1 = plt.gcf()
                plt.draw()
                fig1.savefig('bestfitimage/' + str(car) + '.png')
                outfile = open('finalfile.csv', 'a')
                writer = csv.writer(outfile)
                writer.writerow([man1,car,a,b])
# Out:
# /home/saksham/Desktop/majorproject/out1/BMW.csv
# BMW.csv
# running
# [ 1345908.63636364  2416666.66666667  3700000.          2155000.          1810000.1
#   3250000.          1512340.66666667]
# [ 6.          2.66666667  1.          4.75        4.3         1.
#   5.46666667]
# 6.0
# 2.66666666667
# 1.0
# 4.75
# 4.3
# 1.0
# 5.46666666667
# 1345908.63636
# 2416666.66667
# 3700000.0
# 2155000.0
# 1810000.1
# 3250000.0
# 1512340.66667
# best fit line:
# y = 3795623.87 +  -412155.57x
# BMW.csv
# running
# [ 2955000.  4650000.  2500000.  3500000.  4200000.  2793750.]
# [ 4.6         1.5         5.33333333  3.          2.          4.75      ]
# 4.6
# 1.5
# 5.33333333333
# 3.0
# 2.0
# 4.75
# 2955000.0
# 4650000.0
# 2500000.0
# 3500000.0
# 4200000.0
# 2793750.0
# best fit line:
# y = 5293287.31 +  -526875.24x
# BMW.csv
# running
# [ 3533333.33333333  6800000.          5753333.33333333  2300000.          1600000.        ]
# [ 5.66666667  2.          2.66666667  7.          7.        ]
# 5.66666666667
# 2.0
# 2.66666666667
# 7.0
# 7.0
# 3533333.33333
# 6800000.0
# 5753333.33333
# 2300000.0
# 1600000.0
# best fit line:
# y = 8480643.27 +  -921228.07x
# BMW.csv
# running
# [ 3670000.  6600000.  4500000.  3816333.]
# [ 7.          3.          5.66666667  7.        ]
# 7.0
# 3.0
# 5.66666666667
# 7.0
# 3670000.0
# 6600000.0
# 4500000.0
# 3816333.0
# best fit line:
# y = 8693764.04 +  -714208.38x
# BMW.csv
# running
# [ 4250000.]
# [ 6.]
# 6.0
# 4250000.0
# best fit line:
# y = nan +  nanx
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:77: RuntimeWarning: invalid value encountered in double_scalars
# /home/saksham/Desktop/majorproject/out1/Renault.csv
# Renault.csv
# running
# [ 360000.  398750.]
# [ 1.66666667  1.5       ]
# 1.66666666667
# 1.5
# 360000.0
# 398750.0
# best fit line:
# y = 747500.00 +  -232500.00x
# Renault.csv
# running
# [ 500000.          354166.33333333  625000.        ]
# [ 4.  5.  2.]
# 4.0
# 5.0
# 2.0
# 500000.0
# 354166.333333
# 625000.0
# best fit line:
# y = 809524.05 +  -86309.62x
# Renault.csv
# running
# [ 600000.          470000.          655000.          522666.66666667]
# [ 4.16666667  5.          4.5         4.33333333]
# 4.16666666667
# 5.0
# 4.5
# 4.33333333333
# 600000.0
# 470000.0
# 655000.0
# 522666.666667
# best fit line:
# y = 1164916.67 +  -134000.00x
# Renault.csv
# running
# [  974000.          1183333.33333333]
# [ 1.6  2. ]
# 1.6
# 2.0
# 974000.0
# 1183333.33333
# best fit line:
# y = 136666.67 +  523333.33x
# Renault.csv
# running
# [ 761302.17391304  877140.          661041.63888889  996333.33333333
#   710044.37777778  805999.93181818]
# [ 4.17391304  2.76        4.13888889  2.          4.33333333  3.97727273]
# 4.17391304348
# 2.76
# 4.13888888889
# 2.0
# 4.33333333333
# 3.97727272727
# 761302.173913
# 877140.0
# 661041.638889
# 996333.333333
# 710044.377778
# 805999.931818
# best fit line:
# y = 1223685.27 +  -118327.73x
# Renault.csv
# running
# [  666666.66666667  1400000.           843750.           552499.83333333]
# [ 5.66666667  4.          3.75        5.66666667]
# 5.66666666667
# 4.0
# 3.75
# 5.66666666667
# 666666.666667
# 1400000.0
# 843750.0
# 552499.833333
# best fit line:
# y = 2114361.45 +  -261722.06x
# Renault.csv
# running
# [ 1550000.   1012499.5  1900000.   1325000.   1650000. ]
# [ 5.   6.   3.   5.5  4. ]
# 5.0
# 6.0
# 3.0
# 5.5
# 4.0
# 1550000.0
# 1012499.5
# 1900000.0
# 1325000.0
# 1650000.0
# best fit line:
# y = 2738470.25 +  -266163.91x
# /home/saksham/Desktop/majorproject/out1/Hyundai.csv
# Hyundai.csv
# running
# [ 250465.11627907  356666.85714286  274924.50943396  223337.46666667
#   313228.54285714  407499.75      ]
# [ 4.34883721  1.85714286  3.96226415  5.03333333  2.94285714  1.        ]
# 4.3488372093
# 1.85714285714
# 3.96226415094
# 5.03333333333
# 2.94285714286
# 1.0
# 250465.116279
# 356666.857143
# 274924.509434
# 223337.466667
# 313228.542857
# 407499.75
# best fit line:
# y = 446240.61 +  -44468.35x
# Hyundai.csv
# running
# [ 349919.54022989  278889.03448276  218546.42857143  250056.11235955
#   432304.69565217  315233.85483871  382166.66666667]
# [ 5.01149425  5.86896552  6.89285714  6.5505618   2.39130435  5.72580645
#   4.05      ]
# 5.01149425287
# 5.86896551724
# 6.89285714286
# 6.55056179775
# 2.39130434783
# 5.72580645161
# 4.05
# 349919.54023
# 278889.034483
# 218546.428571
# 250056.11236
# 432304.695652
# 315233.854839
# 382166.666667
# best fit line:
# y = 563035.38 +  -46974.10x
# Hyundai.csv
# running
# [ 532200.          727000.          200000.          619476.19047619]
# [ 2.6         2.4         1.          2.33333333]
# 2.6
# 2.4
# 1.0
# 2.33333333333
# 532200.0
# 727000.0
# 200000.0
# 619476.190476
# best fit line:
# y = -56460.17 +  276542.03x
# Hyundai.csv
# running
# [  774540.98360656   655692.29059829   367037.03703704   472882.72340426
#   1074900.           562745.84042553   911774.09677419]
# [ 3.42622951  4.94871795  7.          6.17021277  1.8         5.35106383
#   2.51612903]
# 3.4262295082
# 4.94871794872
# 7.0
# 6.17021276596
# 1.8
# 5.35106382979
# 2.51612903226
# 774540.983607
# 655692.290598
# 367037.037037
# 472882.723404
# 1074900.0
# 562745.840426
# 911774.096774
# best fit line:
# y = 1260373.54 +  -128251.84x
# Hyundai.csv
# running
# [  858571.42857143  1290000.          1097916.66666667  1428750.           984000.        ]
# [ 4.71428571  3.          4.25        2.25        4.25      ]
# 4.71428571429
# 3.0
# 4.25
# 2.25
# 4.25
# 858571.428571
# 1290000.0
# 1097916.66667
# 1428750.0
# 984000.0
# best fit line:
# y = 1934357.24 +  -217314.02x
# /home/saksham/Desktop/majorproject/out1/Mercedes-Benz.csv
# Mercedes-Benz.csv
# running
# [ 2800000.  2590000.]
# [ 6.  7.]
# 6.0
# 7.0
# 2800000.0
# 2590000.0
# best fit line:
# y = 4060000.00 +  -210000.00x
# /home/saksham/Desktop/majorproject/out1/Audi.csv
# Audi.csv
# running
# [ 2435500.   5000000.   2394999.5]
# [ 2.5  1.   2. ]
# 2.5
# 1.0
# 2.0
# 2435500.0
# 5000000.0
# 2394999.5
# best fit line:
# y = 6645714.25 +  -1837571.50x
# Audi.csv
# running
# [ 2637500.  3100000.  2809375.  2425000.]
# [ 3.     2.5    3.375  5.   ]
# 3.0
# 2.5
# 3.375
# 5.0
# 2637500.0
# 3100000.0
# 2809375.0
# 2425000.0
# best fit line:
# y = 3522858.73 +  -224833.15x
# Audi.csv
# running
# [ 3651666.66666667  2107692.30769231  1488947.31578947  2583636.36363636
#   3029999.8         1772500.          2368922.92307692]
# [ 2.          5.          6.47368421  3.18181818  1.6         5.9
#   3.61538462]
# 2.0
# 5.0
# 6.47368421053
# 3.18181818182
# 1.6
# 5.9
# 3.61538461538
# 3651666.66667
# 2107692.30769
# 1488947.31579
# 2583636.36364
# 3029999.8
# 1772500.0
# 2368922.92308
# best fit line:
# y = 3897793.00 +  -370214.52x
# Audi.csv
# running
# [ 2550000.          3550166.66666667  2124750.          4100000.          3172500.
#   2377333.33333333]
# [ 5.625       3.33333333  6.5         2.          4.5         6.        ]
# 5.625
# 3.33333333333
# 6.5
# 2.0
# 4.5
# 6.0
# 2550000.0
# 3550166.66667
# 2124750.0
# 4100000.0
# 3172500.0
# 2377333.33333
# best fit line:
# y = 5021371.33 +  -438276.41x
# Audi.csv
# running
# [ 2321666.66666667  3634600.          1864999.8         3019999.8
#   2730615.38461538  1453750.        ]
# [ 5.66666667  2.8         6.2         4.3         4.53846154  7.        ]
# 5.66666666667
# 2.8
# 6.2
# 4.3
# 4.53846153846
# 7.0
# 2321666.66667
# 3634600.0
# 1864999.8
# 3019999.8
# 2730615.38462
# 1453750.0
# best fit line:
# y = 5157846.51 +  -521926.91x
# Audi.csv
# running
# [ 3890000.]
# [ 4.]
# 4.0
# 3890000.0
# best fit line:
# y = nan +  nanx
# Audi.csv
# running
# [ 3961000.          2600000.          4520000.          5450000.          3512500.
#   4366666.66666667]
# [ 4.8         7.          4.          2.          6.          3.33333333]
# 4.8
# 7.0
# 4.0
# 2.0
# 6.0
# 3.33333333333
# 3961000.0
# 2600000.0
# 4520000.0
# 5450000.0
# 3512500.0
# 4366666.66667
# best fit line:
# y = 6423162.46 +  -520717.74x
# Audi.csv
# running
# [ 8250000.]
# [ 5.]
# 5.0
# 8250000.0
# best fit line:
# y = nan +  nanx
# /home/saksham/Desktop/majorproject/out1/Honda.csv
# Honda.csv
# running
# [ 345964.25        448600.          413615.30769231  378833.27777778
#   501250.          319795.31578947]
# [ 4.89285714  3.2         3.84615385  4.77777778  2.          4.68421053]
# 4.89285714286
# 3.2
# 3.84615384615
# 4.77777777778
# 2.0
# 4.68421052632
# 345964.25
# 448600.0
# 413615.307692
# 378833.277778
# 501250.0
# 319795.315789
# best fit line:
# y = 619574.15 +  -55954.31x
# Honda.csv
# running
# [ 590724.10344828  541517.85714286  490447.34210526  729800.
#   634363.63636364]
# [ 3.27586207  3.35714286  3.63157895  1.4         2.09090909]
# 3.27586206897
# 3.35714285714
# 3.63157894737
# 1.4
# 2.09090909091
# 590724.103448
# 541517.857143
# 490447.342105
# 729800.0
# 634363.636364
# best fit line:
# y = 847734.47 +  -91005.05x
# Honda.csv
# running
# [ 446076.92307692  751666.66666667  340312.4375      672200.          850000.
#   381428.57142857]
# [ 5.46153846  1.83333333  6.75        1.4         2.          6.14285714]
# 5.46153846154
# 1.83333333333
# 6.75
# 1.4
# 2.0
# 6.14285714286
# 446076.923077
# 751666.666667
# 340312.4375
# 672200.0
# 850000.0
# 381428.571429
# best fit line:
# y = 895705.22 +  -81930.17x
# Honda.csv
# running
# [ 867666.66666667  734733.33333333  795499.91666667]
# [ 2.53333333  2.53333333  2.66666667]
# 2.53333333333
# 2.53333333333
# 2.66666666667
# 867666.666667
# 734733.333333
# 795499.916667
# best fit line:
# y = 909501.58 +  -42750.62x
# Honda.csv
# running
# [  433368.13461538   696631.52631579   929479.98         521603.03053435
#    834361.5106383    604813.93023256  1026785.71428571  1248333.33333333]
# [ 6.80769231  4.42105263  2.68        6.04580153  2.80851064  4.93023256
#   2.28571429  1.        ]
# 6.80769230769
# 4.42105263158
# 2.68
# 6.04580152672
# 2.8085106383
# 4.93023255814
# 2.28571428571
# 1.0
# 433368.134615
# 696631.526316
# 929479.98
# 521603.030534
# 834361.510638
# 604813.930233
# 1026785.71429
# 1248333.33333
# best fit line:
# y = 1308589.18 +  -134714.99x
# Honda.csv
# running
# [  808999.94736842   661062.3125      1625000.          1014833.33333333
#    375000.        ]
# [ 6.10526316  6.9375      4.          5.          1.        ]
# 6.10526315789
# 6.9375
# 4.0
# 5.0
# 1.0
# 808999.947368
# 661062.3125
# 1625000.0
# 1014833.33333
# 375000.0
# best fit line:
# y = 721938.63 +  37981.66x
# /home/saksham/Desktop/majorproject/out1/Fiat.csv
# Fiat.csv
# running
# [ 401785.71428571  299769.23076923  560000.          227142.85714286
#   470700.        ]
# [ 5.5         6.38461538  5.          6.85714286  4.4       ]
# 5.5
# 6.38461538462
# 5.0
# 6.85714285714
# 4.4
# 401785.714286
# 299769.230769
# 560000.0
# 227142.857143
# 470700.0
# best fit line:
# y = 1061058.40 +  -118894.28x
# /home/saksham/Desktop/majorproject/out1/Skoda.csv
# Skoda.csv
# running
# [  489777.55555556   758889.           586934.86206897  1019090.90909091
#    869727.27272727   671944.44444444]
# [ 4.95555556  2.88888889  4.48275862  1.81818182  2.36363636  3.61111111]
# 4.95555555556
# 2.88888888889
# 4.48275862069
# 1.81818181818
# 2.36363636364
# 3.61111111111
# 489777.555556
# 758889.0
# 586934.862069
# 1019090.90909
# 869727.272727
# 671944.444444
# best fit line:
# y = 1252710.94 +  -155063.67x
# Skoda.csv
# running
# [ 1950000.   1060000.    465000.   1524997.5  1350000.5]
# [ 2.   3.   3.   3.5  4. ]
# 2.0
# 3.0
# 3.0
# 3.5
# 4.0
# 1950000.0
# 1060000.0
# 465000.0
# 1524997.5
# 1350000.5
# best fit line:
# y = 1935795.83 +  -214772.98x
# Skoda.csv
# running
# [  753928.57142857  1800000.          1032500.           893750.          2000000.
#    625000.        ]
# [ 5.28571429  2.          5.75        5.25        2.          7.        ]
# 5.28571428571
# 2.0
# 5.75
# 5.25
# 2.0
# 7.0
# 753928.571429
# 1800000.0
# 1032500.0
# 893750.0
# 2000000.0
# 625000.0
# best fit line:
# y = 2395808.15 +  -266427.71x
# Skoda.csv
# running
# [  668358.97435897  1175000.           986857.          1435000.2
#    841933.26666667  1850000.        ]
# [ 6.69230769  5.          5.57142857  3.6         6.6         2.        ]
# 6.69230769231
# 5.0
# 5.57142857143
# 3.6
# 6.6
# 2.0
# 668358.974359
# 1175000.0
# 986857.0
# 1435000.2
# 841933.266667
# 1850000.0
# best fit line:
# y = 2307455.98 +  -233764.87x
# /home/saksham/Desktop/majorproject/out1/Maruti Suzuki.csv
# Maruti Suzuki.csv
# running
# [ 331312.5         246663.04347826  294892.82142857  268682.92682927
#   219650.          379750.          157500.        ]
# [ 1.75        3.73913043  2.21428571  3.48780488  4.5         1.          7.        ]
# 1.75
# 3.73913043478
# 2.21428571429
# 3.48780487805
# 4.5
# 1.0
# 7.0
# 331312.5
# 246663.043478
# 294892.821429
# 268682.926829
# 219650.0
# 379750.0
# 157500.0
# best fit line:
# y = 391914.80 +  -35665.21x
# Maruti Suzuki.csv
# running
# [ 177317.24137931  246500.          127200.          278666.66666667
#   200214.28571429  158391.30434783  225833.33333333]
# [ 6.24137931  3.42105263  6.9         2.33333333  5.14285714  6.43478261
#   4.16666667]
# 6.24137931034
# 3.42105263158
# 6.9
# 2.33333333333
# 5.14285714286
# 6.4347826087
# 4.16666666667
# 177317.241379
# 246500.0
# 127200.0
# 278666.666667
# 200214.285714
# 158391.304348
# 225833.333333
# best fit line:
# y = 351843.55 +  -30276.55x
# Maruti Suzuki.csv
# running
# [ 221666.66666667  314130.43478261  276650.          392809.52380952
#   250086.95652174  190647.11764706  352888.88888889]
# [ 6.16666667  3.43478261  4.7         1.66666667  5.80434783  6.29411765
#   2.05555556]
# 6.16666666667
# 3.4347826087
# 4.7
# 1.66666666667
# 5.80434782609
# 6.29411764706
# 2.05555555556
# 221666.666667
# 314130.434783
# 276650.0
# 392809.52381
# 250086.956522
# 190647.117647
# 352888.888889
# best fit line:
# y = 442364.01 +  -36440.59x
# Maruti Suzuki.csv
# running
# [ 512272.72727273  439720.          403181.81818182  473076.92307692]
# [ 1.72727273  2.52        2.90909091  2.15384615]
# 1.72727272727
# 2.52
# 2.90909090909
# 2.15384615385
# 512272.727273
# 439720.0
# 403181.818182
# 473076.923077
# best fit line:
# y = 671645.10 +  -92192.22x
# Maruti Suzuki.csv
# running
# [ 463598.29059829  353323.33        569595.23809524  290175.92592593
#   410461.472       663096.15384615  516907.88596491]
# [ 4.61538462  6.33        3.03571429  7.          5.496       1.88461538
#   3.81578947]
# 4.61538461538
# 6.33
# 3.03571428571
# 7.0
# 5.496
# 1.88461538462
# 3.81578947368
# 463598.290598
# 353323.33
# 569595.238095
# 290175.925926
# 410461.472
# 663096.153846
# 516907.885965
# best fit line:
# y = 789541.23 +  -70223.92x
# Maruti Suzuki.csv
# running
# [ 754000.          869571.42857143  501000.        ]
# [ 1.6         1.42857143  2.        ]
# 1.6
# 1.42857142857
# 2.0
# 754000.0
# 869571.428571
# 501000.0
# best fit line:
# y = 1785620.25 +  -642784.81x
# Maruti Suzuki.csv
# running
# [ 450000.  270000.  512500.]
# [ 5.  5.  5.]
# 5.0
# 5.0
# 5.0
# 450000.0
# 270000.0
# 512500.0
# best fit line:
# y = nan +  nanx
# Maruti Suzuki.csv
# running
# [ 547766.63333333  693676.90769231  768250.          623372.88135593
#   850550.        ]
# [ 4.86666667  3.58461538  3.          4.59322034  2.08333333]
# 4.86666666667
# 3.58461538462
# 3.0
# 4.59322033898
# 2.08333333333
# 547766.633333
# 693676.907692
# 768250.0
# 623372.881356
# 850550.0
# best fit line:
# y = 1068182.54 +  -102455.49x
# Maruti Suzuki.csv
# running
# [ 1068418.75         796190.47619048   920146.        ]
# [ 1.          2.23809524  1.89473684]
# 1.0
# 2.2380952381
# 1.89473684211
# 1068418.75
# 796190.47619
# 920146.0
# best fit line:
# y = 1285799.31 +  -208976.77x
# /home/saksham/Desktop/majorproject/out1/Mitsubishi.csv
# /home/saksham/Desktop/majorproject/out1/Nissan.csv
# Nissan.csv
# running
# [ 285210.52631579  358157.89473684  455000.          218500.          570000.
#   326923.07692308  400000.        ]
# [ 5.89473684  5.          2.85714286  7.          2.          5.69230769
#   4.8       ]
# 5.89473684211
# 5.0
# 2.85714285714
# 7.0
# 2.0
# 5.69230769231
# 4.8
# 285210.526316
# 358157.894737
# 455000.0
# 218500.0
# 570000.0
# 326923.076923
# 400000.0
# best fit line:
# y = 679582.70 +  -64471.04x
# Nissan.csv
# running
# [ 468434.7826087   748125.          604400.          250000.
#   400285.71428571  531304.17391304]
# [ 5.04347826  2.625       3.9         1.          5.          4.47826087]
# 5.04347826087
# 2.625
# 3.9
# 1.0
# 5.0
# 4.47826086957
# 468434.782609
# 748125.0
# 604400.0
# 250000.0
# 400285.714286
# 531304.173913
# best fit line:
# y = 418206.62 +  22375.64x
# Nissan.csv
# running
# [  849153.69230769  1059444.44444444   966785.78571429  1225000.        ]
# [ 2.84615385  2.66666667  3.14285714  2.        ]
# 2.84615384615
# 2.66666666667
# 3.14285714286
# 2.0
# 849153.692308
# 1059444.44444
# 966785.785714
# 1225000.0
# best fit line:
# y = 1754583.37 +  -273839.89x
# /home/saksham/Desktop/majorproject/out1/Volkswagen.csv
# Volkswagen.csv
# running
# [ 577447.36842105  362878.22826087  424810.34482759  301007.56060606
#   746555.55555556  489954.84090909  663727.21212121]
# [ 3.44736842  5.84782609  5.20689655  6.36363636  1.88888889  4.38636364
#   2.42424242]
# 3.44736842105
# 5.84782608696
# 5.20689655172
# 6.36363636364
# 1.88888888889
# 4.38636363636
# 2.42424242424
# 577447.368421
# 362878.228261
# 424810.344828
# 301007.560606
# 746555.555556
# 489954.840909
# 663727.212121
# best fit line:
# y = 908739.85 +  -94529.91x
# Volkswagen.csv
# running
# [  696799.96         440760.48275862  1035000.           585575.75757576
#    494533.48         866111.           388392.78571429]
# [ 3.88        6.02298851  1.84615385  4.81818182  5.73333333  2.66666667
#   6.23809524]
# 3.88
# 6.02298850575
# 1.84615384615
# 4.81818181818
# 5.73333333333
# 2.66666666667
# 6.2380952381
# 696799.96
# 440760.482759
# 1035000.0
# 585575.757576
# 494533.48
# 866111.0
# 388392.785714
# best fit line:
# y = 1255657.13 +  -137233.42x
# Volkswagen.csv
# running
# [  631250.          1445000.           822428.57142857  1816666.66666667
#   1071333.33333333   476998.57142857  2300000.        ]
# [ 6.375       3.          6.07142857  2.33333333  5.          6.85714286
#   2.        ]
# 6.375
# 3.0
# 6.07142857143
# 2.33333333333
# 5.0
# 6.85714285714
# 2.0
# 631250.0
# 1445000.0
# 822428.571429
# 1816666.66667
# 1071333.33333
# 476998.571429
# 2300000.0
# best fit line:
# y = 2649843.93 +  -315619.70x
# Volkswagen.csv
# running
# [ 1850000.  1475000.  1650000.]
# [ 7.   5.5  7. ]
# 7.0
# 5.5
# 7.0
# 1850000.0
# 1475000.0
# 1650000.0
# best fit line:
# y = 466666.67 +  183333.33x
# /home/saksham/Desktop/majorproject/out1/Mahindra.csv
# Mahindra.csv
# running
# [ 1055000.           577777.77777778   335000.           775625.           887500.
#    685000.        ]
# [ 1.5         5.44444444  1.          3.5         1.5         4.16666667]
# 1.5
# 5.44444444444
# 1.0
# 3.5
# 1.5
# 4.16666666667
# 1055000.0
# 577777.777778
# 335000.0
# 775625.0
# 887500.0
# 685000.0
# best fit line:
# y = 780990.40 +  -21625.69x
# Mahindra.csv
# running
# [ 456000.          678461.46153846  568794.17647059  754375.
#   500380.80952381  411666.66666667  619400.        ]
# [ 6.2         3.07692308  4.76470588  2.5         5.66666667  6.33333333
#   3.7       ]
# 6.2
# 3.07692307692
# 4.76470588235
# 2.5
# 5.66666666667
# 6.33333333333
# 3.7
# 456000.0
# 678461.461538
# 568794.176471
# 754375.0
# 500380.809524
# 411666.666667
# 619400.0
# best fit line:
# y = 934028.72 +  -79063.09x
# Mahindra.csv
# running
# [ 465615.38461538  338124.9375      820000.          267916.66666667
#   730000.          389444.44444444  571666.66666667]
# [ 4.30769231  5.375       1.          5.58333333  1.5         5.11111111
#   2.        ]
# 4.30769230769
# 5.375
# 1.0
# 5.58333333333
# 1.5
# 5.11111111111
# 2.0
# 465615.384615
# 338124.9375
# 820000.0
# 267916.666667
# 730000.0
# 389444.444444
# 571666.666667
# best fit line:
# y = 868192.46 +  -100275.97x
# Mahindra.csv
# running
# [ 470403.47368421  672666.66666667  336562.5         866666.66666667
#   558048.7804878   248888.88888889  404812.77083333]
# [ 5.45614035  3.22222222  5.625       1.          5.24390244  7.          5.9375    ]
# 5.45614035088
# 3.22222222222
# 5.625
# 1.0
# 5.24390243902
# 7.0
# 5.9375
# 470403.473684
# 672666.666667
# 336562.5
# 866666.666667
# 558048.780488
# 248888.888889
# 404812.770833
# best fit line:
# y = 989994.56 +  -100699.89x
# Mahindra.csv
# running
# [  754431.74285714   606684.88043478  1047440.           874151.48484848
#    668891.54216867  1183181.81818182   535309.5       ]
# [ 4.4         6.27173913  2.6         3.45454545  5.78313253  2.09090909
#   6.9047619 ]
# 4.4
# 6.27173913043
# 2.6
# 3.45454545455
# 5.78313253012
# 2.09090909091
# 6.90476190476
# 754431.742857
# 606684.880435
# 1047440.0
# 874151.484848
# 668891.542169
# 1183181.81818
# 535309.5
# best fit line:
# y = 1367884.50 +  -123951.42x
# Mahindra.csv
# running
# [ 1837500.           962038.16363636  1243571.42857143   814064.8961039
#   1569260.86956522  1102265.36111111]
# [ 1.          4.6         3.08571429  5.20779221  1.73913043  3.5       ]
# 1.0
# 4.6
# 3.08571428571
# 5.20779220779
# 1.73913043478
# 3.5
# 1837500.0
# 962038.163636
# 1243571.42857
# 814064.896104
# 1569260.86957
# 1102265.36111
# best fit line:
# y = 2006505.27 +  -235740.16x
# /home/saksham/Desktop/majorproject/out1/Tata.csv
# Tata.csv
# running
# [  59344.48648649  132916.66666667   98393.33870968  310000.          182299.1875
#    77935.05194805  229000.        ]
# [ 6.28378378  3.41666667  5.32258065  1.          2.625       5.72727273
#   2.        ]
# 6.28378378378
# 3.41666666667
# 5.32258064516
# 1.0
# 2.625
# 5.72727272727
# 2.0
# 59344.4864865
# 132916.666667
# 98393.3387097
# 310000.0
# 182299.1875
# 77935.0519481
# 229000.0
# best fit line:
# y = 317180.63 +  -42857.35x
# Tata.csv
# running
# [ 192857.14285714  271666.66666667  350000.          235030.75      ]
# [ 5.          4.83333333  5.          5.25      ]
# 5.0
# 4.83333333333
# 5.0
# 5.25
# 192857.142857
# 271666.666667
# 350000.0
# 235030.75
# best fit line:
# y = 737913.41 +  -94710.33x
# Tata.csv
# running
# [ 600000.  677000.  490000.]
# [ 2.42857143  1.8         2.5       ]
# 2.42857142857
# 1.8
# 2.5
# 600000.0
# 677000.0
# 490000.0
# best fit line:
# y = 1060539.89 +  -210240.72x
# Tata.csv
# running
# [ 546250.          394684.21052632  474160.          725000.          632500.        ]
# [ 5.08333333  6.73684211  5.96        3.5         5.        ]
# 5.08333333333
# 6.73684210526
# 5.96
# 3.5
# 5.0
# 546250.0
# 394684.210526
# 474160.0
# 725000.0
# 632500.0
# best fit line:
# y = 1102000.84 +  -104162.55x
# Tata.csv
# running
# [ 692500.          458333.33333333  567500.          660000.          600000.
#   500000.        ]
# [ 3.5         5.66666667  5.5         5.          5.          4.5       ]
# 3.5
# 5.66666666667
# 5.5
# 5.0
# 5.0
# 4.5
# 692500.0
# 458333.333333
# 567500.0
# 660000.0
# 600000.0
# 500000.0
# best fit line:
# y = 921315.79 +  -70270.68x
# /home/saksham/Desktop/majorproject/out1/Ford.csv
# Ford.csv
# running
# [ 249346.15384615  390270.58974359  323200.          447206.89655172
#   276183.67346939  353676.47058824  300290.32258065]
# [ 6.34615385  4.43589744  6.32727273  3.          6.34693878  5.19117647
#   6.14516129]
# 6.34615384615
# 4.4358974359
# 6.32727272727
# 3.0
# 6.34693877551
# 5.19117647059
# 6.14516129032
# 249346.153846
# 390270.589744
# 323200.0
# 447206.896552
# 276183.673469
# 353676.470588
# 300290.322581
# best fit line:
# y = 605901.78 +  -50304.51x
# Ford.csv
# running
# [  867615.38461538   739199.8          804107.88571429   674733.26666667
#   1043125.        ]
# [ 2.30769231  3.74285714  3.          3.9         1.        ]
# 2.30769230769
# 3.74285714286
# 3.0
# 3.9
# 1.0
# 867615.384615
# 739199.8
# 804107.885714
# 674733.266667
# 1043125.0
# best fit line:
# y = 1155324.53 +  -118120.17x
# Ford.csv
# running
# [  752222.          1085000.           885913.04347826  1400000.          1188750.
#   1600000.        ]
# [ 5.          5.          6.56521739  4.          5.          3.        ]
# 5.0
# 5.0
# 6.5652173913
# 4.0
# 5.0
# 3.0
# 752222.0
# 1085000.0
# 885913.043478
# 1400000.0
# 1188750.0
# 1600000.0
# best fit line:
# y = 2197371.99 +  -219579.88x
# /home/saksham/Desktop/majorproject/out1/Toyota.csv
# Toyota.csv
# running
# [ 1273094.75862069  2181500.          1693273.46153846  2443531.25
#   1931064.51612903  2791750.          1407031.25      ]
# [ 6.96551724  3.73076923  5.07692308  2.8125      4.48387097  1.75        6.25      ]
# 6.96551724138
# 3.73076923077
# 5.07692307692
# 2.8125
# 4.48387096774
# 1.75
# 6.25
# 1273094.75862
# 2181500.0
# 1693273.46154
# 2443531.25
# 1931064.51613
# 2791750.0
# 1407031.25
# best fit line:
# y = 3281602.08 +  -297717.87x
# Toyota.csv
# running
# [  875666.66666667  1600000.           650000.        ]
# [ 6.66666667  5.          7.        ]
# 6.66666666667
# 5.0
# 7.0
# 875666.666667
# 1600000.0
# 650000.0
# best fit line:
# y = 3916354.84 +  -461967.74x
# Toyota.csv
# running
# [ 1299999.]
# [ 6.]
# 6.0
# 1299999.0
# best fit line:
# y = nan +  nanx
# /home/saksham/Desktop/majorproject/out1/Chevrolet.csv
# Chevrolet.csv
# running
# [ 146538.46153846  228875.          193480.          280400.
#   210100.09090909  171742.85714286]
# [ 7.          6.          6.16        3.8         6.09090909  6.08571429]
# 7.0
# 6.0
# 6.16
# 3.8
# 6.09090909091
# 6.08571428571
# 146538.461538
# 228875.0
# 193480.0
# 280400.0
# 210100.090909
# 171742.857143
# best fit line:
# y = 437530.53 +  -39675.04x
# Chevrolet.csv
# running
# [ 383312.72727273  222403.49122807  326999.95238095  285180.51388889
#   192800.44        444000.          251131.08196721]
# [ 3.31818182  6.14035088  4.47619048  5.18055556  6.88        1.8
#   5.68852459]
# 3.31818181818
# 6.14035087719
# 4.47619047619
# 5.18055555556
# 6.88
# 1.8
# 5.68852459016
# 383312.727273
# 222403.491228
# 326999.952381
# 285180.513889
# 192800.44
# 444000.0
# 251131.081967
# best fit line:
# y = 545825.67 +  -51217.35x
# Chevrolet.csv
# running
# [ 346666.66666667  550000.          447571.42857143]
# [ 3.83333333  3.2         3.42857143]
# 3.83333333333
# 3.2
# 3.42857142857
# 346666.666667
# 550000.0
# 447571.428571
# best fit line:
# y = 1538771.44 +  -312761.04x
# Chevrolet.csv
# running
# [ 463769.23076923  186500.          599000.          683333.33333333
#   409435.09090909  528916.66666667]
# [ 3.69230769  3.25        3.4         2.33333333  4.          3.08333333]
# 3.69230769231
# 3.25
# 3.4
# 2.33333333333
# 4.0
# 3.08333333333
# 463769.230769
# 186500.0
# 599000.0
# 683333.333333
# 409435.090909
# 528916.666667
# best fit line:
# y = 953918.31 +  -144367.59x
# Chevrolet.csv
# running
# [ 732909.09090909  424722.22222222  650454.63636364  807500.
#   572727.27272727  980000.          494615.38461538]
# [ 3.18181818  5.94444444  4.18181818  2.5         4.90909091  1.
#   5.92307692]
# 3.18181818182
# 5.94444444444
# 4.18181818182
# 2.5
# 4.90909090909
# 1.0
# 5.92307692308
# 732909.090909
# 424722.222222
# 650454.636364
# 807500.0
# 572727.272727
# 980000.0
# 494615.384615
# best fit line:
# y = 1074913.36 +  -103525.30x
# Chevrolet.csv
# running
# [ 1800000.           762370.37037037   565650.71428571  1061000.
#    661303.78461538  1468750.           875058.82352941]
# [ 1.5         5.74074074  6.85714286  3.7         6.18461538  2.25
#   4.52941176]
# 1.5
# 5.74074074074
# 6.85714285714
# 3.7
# 6.18461538462
# 2.25
# 4.52941176471
# 1800000.0
# 762370.37037
# 565650.714286
# 1061000.0
# 661303.784615
# 1468750.0
# 875058.823529
# best fit line:
# y = 1989694.05 +  -218898.13x
