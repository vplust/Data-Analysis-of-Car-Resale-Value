# %%
import csv

# %%
manufacturers = []

# %%
 with open('car_list.csv', 'rt') as f:
        reader = csv.reader(f)
        for row in reader:
            manufacturers.append(row[0])

# %%
manufacturers  = manufacturers[1:]
manufacturers
# Out:
# ['Audi',
#  'Audi',
#  'Audi',
#  'Audi',
#  'Audi',
#  'Audi',
#  'Audi',
#  'Audi',
#  'Audi',
#  'Audi',
#  'Audi',
#  'Audi',
#  'Audi',
#  'BMW',
#  'BMW',
#  'BMW',
#  'BMW',
#  'BMW',
#  'BMW',
#  'BMW',
#  'BMW',
#  'BMW',
#  'BMW',
#  'BMW',
#  'BMW',
#  'BMW',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Datsun',
#  'Datsun',
#  'Datsun',
#  'Fiat',
#  'Fiat',
#  'Fiat',
#  'Fiat',
#  'Fiat',
#  'Fiat',
#  'Fiat',
#  'Fiat',
#  'Force Motors',
#  'Force Motors',
#  'Ford',
#  'Ford',
#  'Ford',
#  'Ford',
#  'Ford',
#  'Honda',
#  'Honda',
#  'Honda',
#  'Honda',
#  'Honda',
#  'Honda',
#  'Honda',
#  'Honda',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Hyundai',
#  'Jaguar',
#  'Jaguar',
#  'Jaguar',
#  'Jaguar',
#  'Jaguar',
#  'Land Rover',
#  'Land Rover',
#  'Land Rover',
# ...

# %%
set_manunfacturers = set(manufacturers)

# %%
for manufacturer in set_manunfacturers:
    outfile = open('./' + str(manufacturer) + '.csv', 'w')
    writer = csv.writer(outfile)
    writer.writerow(' ')

# %%
with open('olx_cleaned_data.csv', 'rt') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Maruti suzuki omni van', 'Bengaluru', 'Maruti Suzuki', 'Omni', '2010', 'Petrol', '24000', '210000']
# ['Skoda Rapid 1.5 Tdi Cr Ambition (make Year 2012) (diesel)', 'Bengaluru', 'Skoda', 'Rapid', '2012', 'Diesel', '53000', '530000']
# ['Chevrolet Beat Lt Petrol (make Year 2013) (petrol)', 'Bengaluru', 'Chevrolet', 'Beat', '2013', 'Petrol', '26000', '365000']
# ['2010 Maruti Suzuki Swift diesel 52000 Kms', 'Bengaluru', 'Maruti Suzuki', 'Swift', '2010', 'Diesel', '52000', '550000']
# ['Hyundai I10 Sportz 1.2 (make Year 2010) (petrol)', 'Bengaluru', 'Hyundai', 'I10', '2010', 'Petrol', '62000', '305000']
# ['Honda Brio S Mt (make Year 2012) (petrol)', 'Bengaluru', 'Honda', 'Brio', '2012', 'Petrol', '52000', '379000']
# ['Hyundai Eon 1.0 Kappa Magna + (make Year 2013) (petrol)', 'Bengaluru', 'Hyundai', 'Eon', '2013', 'Petrol', '32000', '305000']
# ['Chevrolet Beat Ps Diesel (make Year 2012) (diesel)', 'Bengaluru', 'Chevrolet', 'Beat', '2012', 'Diesel', '48000', '325000']
# ...

# %%
count = 1 
with open('olx_cleaned_data.csv', 'rt') as f:
        reader = csv.reader(f)
        for row in reader:
            count = count  + 1
            man = row[2]
            print(str(man))
            outfile = open('./' + str(man) + '.csv', 'a')
            writer = csv.writer(outfile)
            writer.writerow(row)
# Out:
# Maruti Suzuki
# Skoda
# Chevrolet
# Maruti Suzuki
# Hyundai
# Honda
# Hyundai
# Chevrolet
# Volkswagen
# Nissan
# Hyundai
# Volkswagen
# Ford
# Volkswagen
# Maruti Suzuki
# Maruti Suzuki
# Renault
# Ford
# Honda
# Maruti Suzuki
# Mahindra
# Honda
# Hyundai
# Toyota
# Ford
# Tata
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Hyundai
# Hyundai
# Hyundai
# Honda
# Skoda
# Hyundai
# Ford
# Hyundai
# Maruti Suzuki
# Skoda
# Mahindra
# Mahindra
# Ford
# Ford
# Maruti Suzuki
# Honda
# Tata
# Hyundai
# Tata
# Tata
# Chevrolet
# Hyundai
# Honda
# Volkswagen
# Honda
# Honda
# Chevrolet
# Volkswagen
# Volkswagen
# Honda
# Honda
# Maruti Suzuki
# Hyundai
# Honda
# Hyundai
# Volkswagen
# Honda
# Maruti Suzuki
# Maruti Suzuki
# Skoda
# Maruti Suzuki
# Volkswagen
# Ford
# Renault
# BMW
# Honda
# Maruti Suzuki
# Hyundai
# Volkswagen
# Mahindra
# Audi
# Mahindra
# Honda
# Mahindra
# Chevrolet
# Toyota
# Mahindra
# Maruti Suzuki
# Chevrolet
# Maruti Suzuki
# Volkswagen
# Mahindra
# Maruti Suzuki
# ...

# %%
count
# Out:
# 17804
